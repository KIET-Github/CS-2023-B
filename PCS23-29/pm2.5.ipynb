# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('districWise_PM2.5.csv')
df
# Out:
#               dist_name state_name  ST_CEN_CD  DT_CEN_CD  censuscode  Y1998  \
# 0              anantnag         JK          1         14          14   19.7
# 1                badgam         JK          1          2           2   30.2
# 2             bandipore         JK          1          9           9   19.3
# 3              baramula         JK          1          8           8   30.2
# 4                  doda         JK          1         16          16   23.6
# ..                  ...        ...        ...        ...         ...    ...
# 636            nalgonda         TS         36          8         539   21.6
# 637           nizamabad         TS         36          2         533   21.5
# 638          rangareddy         TS         36          6         537   19.5
# 639            warangal         TS         36          9         540   18.5
# 640  data_not_available         JK         99         99           0    NaN
#
# ...

# %% [markdown]
# state = df.groupby('state_name')
# jk = state.get_group('JK')
# jk = jk.drop(['state_name','ST_CEN_CD','DT_CEN_CD','censuscode'],axis = 1)

# %%
newjk = jk.transpose()
newjk
jk.reset_index(level=0, inplace=True)

# %%
newjk.reset_index(level=0, inplace=True)
newjk
# Out:
#         index         0       1          2         3     4          5      6  \
# 0   dist_name  anantnag  badgam  bandipore  baramula  doda  ganderbal  jammu
# 1       Y1998      19.7    30.2       19.3      30.2  23.6       17.4   32.7
# 2       Y1999      20.5    30.0       19.0      29.0  24.4       17.6   32.7
# 3       Y2000      24.6    34.4       22.0      32.9  28.4       21.0   36.3
# 4       Y2001      27.5    38.6       25.4      37.7  30.8       23.8   39.5
# 5       Y2002      28.2    38.1       25.3      36.3  32.0       24.4   38.6
# 6       Y2003      24.3    34.0       23.1      33.1  27.8       21.7   37.5
# 7       Y2004      25.0    34.3       22.7      33.2  27.4       21.7   37.2
# 8       Y2005      21.9    30.8       20.7      30.1  24.7       19.4   36.7
# 9       Y2006      23.4    34.4       22.4      33.7  24.9       20.2   36.4
# 10      Y2007      28.2    38.1       25.6      36.1  28.6       24.3   41.2
# ...

# %%
newjk = newjk.drop(['level_0'],axis = 1)
newjk
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-0e3f51fb2251> in <module>
# ----> 1 newjk = newjk.drop(['level_0'],axis = 1)
#       2 newjk
#
# c:\Users\NITESH MAURYA\anaconda3\envs\machineLearning\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\NITESH MAURYA\anaconda3\envs\machineLearning\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4952                 weight  1.0     0.8
#    4953         """
# -> 4954         return super().drop(
#    4955             labels=labels,
#    4956             axis=axis,
#
# ...

# %%
newjk.columns = newjk.iloc[0]

# %%
newjk
# Out:
# 0   dist_name  anantnag  badgam  bandipore  baramula  doda  ganderbal  jammu  \
# 0   dist_name  anantnag  badgam  bandipore  baramula  doda  ganderbal  jammu
# 1       Y1998      19.7    30.2       19.3      30.2  23.6       17.4   32.7
# 2       Y1999      20.5    30.0       19.0      29.0  24.4       17.6   32.7
# 3       Y2000      24.6    34.4       22.0      32.9  28.4       21.0   36.3
# 4       Y2001      27.5    38.6       25.4      37.7  30.8       23.8   39.5
# 5       Y2002      28.2    38.1       25.3      36.3  32.0       24.4   38.6
# 6       Y2003      24.3    34.0       23.1      33.1  27.8       21.7   37.5
# 7       Y2004      25.0    34.3       22.7      33.2  27.4       21.7   37.2
# 8       Y2005      21.9    30.8       20.7      30.1  24.7       19.4   36.7
# 9       Y2006      23.4    34.4       22.4      33.7  24.9       20.2   36.4
# 10      Y2007      28.2    38.1       25.6      36.1  28.6       24.3   41.2
# ...

# %%
jk = newjk.drop(index=0)
jk
# Out:
# 0  dist_name anantnag badgam bandipore baramula  doda ganderbal jammu kargil  \
# 1      Y1998     19.7   30.2      19.3     30.2  23.6      17.4  32.7   11.3
# 2      Y1999     20.5   30.0      19.0     29.0  24.4      17.6  32.7   12.6
# 3      Y2000     24.6   34.4      22.0     32.9  28.4      21.0  36.3   14.6
# 4      Y2001     27.5   38.6      25.4     37.7  30.8      23.8  39.5   15.8
# 5      Y2002     28.2   38.1      25.3     36.3  32.0      24.4  38.6   16.4
# 6      Y2003     24.3   34.0      23.1     33.1  27.8      21.7  37.5   15.0
# 7      Y2004     25.0   34.3      22.7     33.2  27.4      21.7  37.2   15.6
# 8      Y2005     21.9   30.8      20.7     30.1  24.7      19.4  36.7   14.0
# 9      Y2006     23.4   34.4      22.4     33.7  24.9      20.2  36.4   12.9
# 10     Y2007     28.2   38.1      25.6     36.1  28.6      24.3  41.2   14.3
# 11     Y2008     24.9   34.4      23.4     33.1  26.8      21.4  43.9   13.3
# ...

# %%
jk.rename(columns = {'dist_name':'year'}, inplace = True)

# %%
jk.plot(y = 'pulwama')
# Out:
# <AxesSubplot:>

# %%
jk
# Out:
# 0    year anantnag badgam bandipore baramula  doda ganderbal jammu kargil  \
# 1   Y1998     19.7   30.2      19.3     30.2  23.6      17.4  32.7   11.3
# 2   Y1999     20.5   30.0      19.0     29.0  24.4      17.6  32.7   12.6
# 3   Y2000     24.6   34.4      22.0     32.9  28.4      21.0  36.3   14.6
# 4   Y2001     27.5   38.6      25.4     37.7  30.8      23.8  39.5   15.8
# 5   Y2002     28.2   38.1      25.3     36.3  32.0      24.4  38.6   16.4
# 6   Y2003     24.3   34.0      23.1     33.1  27.8      21.7  37.5   15.0
# 7   Y2004     25.0   34.3      22.7     33.2  27.4      21.7  37.2   15.6
# 8   Y2005     21.9   30.8      20.7     30.1  24.7      19.4  36.7   14.0
# 9   Y2006     23.4   34.4      22.4     33.7  24.9      20.2  36.4   12.9
# 10  Y2007     28.2   38.1      25.6     36.1  28.6      24.3  41.2   14.3
# 11  Y2008     24.9   34.4      23.4     33.1  26.8      21.4  43.9   13.3
# 12  Y2009     22.6   30.7      21.8     29.6  24.3      20.0  39.4   13.8
# ...

# %%
df = df.drop(['ST_CEN_CD','DT_CEN_CD','censuscode'],axis = 1)

# %%
df
# Out:
#               dist_name state_name  Y1998  Y1999  Y2000  Y2001  Y2002  Y2003  \
# 0              anantnag         JK   19.7   20.5   24.6   27.5   28.2   24.3
# 1                badgam         JK   30.2   30.0   34.4   38.6   38.1   34.0
# 2             bandipore         JK   19.3   19.0   22.0   25.4   25.3   23.1
# 3              baramula         JK   30.2   29.0   32.9   37.7   36.3   33.1
# 4                  doda         JK   23.6   24.4   28.4   30.8   32.0   27.8
# ..                  ...        ...    ...    ...    ...    ...    ...    ...
# 636            nalgonda         TS   21.6   23.8   25.3   27.4   26.8   27.8
# 637           nizamabad         TS   21.5   22.8   25.1   27.4   27.3   28.2
# 638          rangareddy         TS   19.5   20.9   22.9   25.3   26.7   27.8
# 639            warangal         TS   18.5   21.5   22.2   24.4   24.5   25.6
# 640  data_not_available         JK    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
# UP. DL, DL, UK, WB, BR, MP, GJ, MH

# %%
mh = state.get_group('MH')
mh = mh.drop(['state_name','ST_CEN_CD','DT_CEN_CD','censuscode'],axis = 1)

# %%
mh = mh.transpose()

mh.reset_index(level=0, inplace=True)
mh.columns = mh.iloc[0]
mh = mh.drop(index=0)
mh.rename(columns = {'dist_name':'year'}, inplace = True)

# %%
mh
# Out:
# 0    year ahmadnagar akola amravati aurangabad bhandara   bid buldana  \
# 1   Y1998       20.5  25.3     24.7       22.0     32.1  18.5    24.6
# 2   Y1999       20.0  25.4     25.4       21.4     36.0  18.6    24.3
# 3   Y2000       27.3  31.0     29.7       27.8     34.3  25.9    30.1
# 4   Y2001       29.3  32.6     32.4       30.1     39.5  28.1    31.6
# 5   Y2002       29.4  33.4     33.2       30.3     38.3  28.6    32.5
# 6   Y2003       31.6  37.3     36.7       33.9     41.0  31.0    36.5
# 7   Y2004       32.4  37.5     36.8       34.3     42.5  30.6    36.7
# 8   Y2005       33.3  37.2     36.1       34.0     40.0  32.3    36.1
# 9   Y2006       35.3  41.1     39.7       37.0     43.0  34.2    39.9
# 10  Y2007       36.0  40.5     39.5       37.6     45.3  35.3    39.5
# 11  Y2008       37.0  43.0     41.4       37.4     49.0  35.9    40.7
# 12  Y2009       37.7  41.8     40.7       37.9     45.3  35.3    40.0
# ...

# %%
plt.figure(figsize=(30,10))
sns.pointplot(y='aurangabad', x='year', data=mh)
# Out:
# <AxesSubplot:xlabel='year', ylabel='aurangabad'>

# %%
df
# Out:
#               dist_name state_name  ST_CEN_CD  DT_CEN_CD  censuscode  Y1998  \
# 0              anantnag         JK          1         14          14   19.7
# 1                badgam         JK          1          2           2   30.2
# 2             bandipore         JK          1          9           9   19.3
# 3              baramula         JK          1          8           8   30.2
# 4                  doda         JK          1         16          16   23.6
# ..                  ...        ...        ...        ...         ...    ...
# 636            nalgonda         TS         36          8         539   21.6
# 637           nizamabad         TS         36          2         533   21.5
# 638          rangareddy         TS         36          6         537   19.5
# 639            warangal         TS         36          9         540   18.5
# 640  data_not_available         JK         99         99           0    NaN
#
# ...

# %%
states = df.groupby(['state_name']).mean()
states
# Out:
#             ST_CEN_CD  DT_CEN_CD  censuscode      Y1998      Y1999      Y2000  \
# state_name
# AN           35.00000   2.000000       639.0  11.766667  11.733333  12.866667
# AP           28.00000  17.000000       548.0  17.684615  19.507692  20.746154
# AR           12.00000   8.500000       252.5   9.150000  11.012500  11.437500
# AS           18.00000  14.000000       313.0  20.159259  21.518519  24.125926
# BR           10.00000  19.500000       221.5  55.215789  55.060526  60.981579
# CG           22.00000   9.500000       408.5  32.044444  33.666667  33.250000
# CH            4.00000   1.000000        55.0  30.600000  31.200000  36.400000
# DD           25.00000   1.500000       494.5  21.950000  21.950000  22.800000
# DL            7.00000   5.000000        94.0  80.588889  82.555556  91.244444
# DN           26.00000   1.000000       496.0  18.800000  19.100000  22.700000
# GA           30.00000   1.500000       585.5  19.650000  20.900000  22.100000
# ...

# %%
# states = states.transpose()

# states
states = states.drop('ST_CEN_CD',axis=1)
states = states.drop('censuscode',axis=1)
states = states.drop('DT_CEN_CD',axis=1)
# states.rename(columns = {'dist_name':'year'}, inplace = True)

# %%
states.head()
# Out:
#                 Y1998      Y1999      Y2000      Y2001      Y2002      Y2003  \
# state_name
# AN          11.766667  11.733333  12.866667  13.066667  13.833333  13.666667
# AP          17.684615  19.507692  20.746154  23.592308  23.653846  24.323077
# AR           9.150000  11.012500  11.437500  14.112500  12.987500  13.456250
# AS          20.159259  21.518519  24.125926  26.044444  25.103704  27.151852
# BR          55.215789  55.060526  60.981579  68.534211  64.700000  68.105263
#
#                 Y2004      Y2005      Y2006      Y2007  ...      Y2011  \
# state_name                                              ...
# AN          15.266667  13.666667  15.533333  14.900000  ...  15.133333
# AP          25.207692  27.261538  27.953846  29.130769  ...  30.969231
# AR          13.331250  14.325000  14.887500  14.000000  ...  14.437500
# AS          27.740741  28.833333  31.633333  30.362963  ...  32.614815
# BR          69.407895  66.973684  75.578947  75.500000  ...  86.997368
#
# ...

# %%
states=states.reset_index()

# %%
states.head()
# Out:
#   state_name      Y1998      Y1999      Y2000      Y2001      Y2002  \
# 0         AN  11.766667  11.733333  12.866667  13.066667  13.833333
# 1         AP  17.684615  19.507692  20.746154  23.592308  23.653846
# 2         AR   9.150000  11.012500  11.437500  14.112500  12.987500
# 3         AS  20.159259  21.518519  24.125926  26.044444  25.103704
# 4         BR  55.215789  55.060526  60.981579  68.534211  64.700000
#
#        Y2003      Y2004      Y2005      Y2006  ...      Y2011      Y2012  \
# 0  13.666667  15.266667  13.666667  15.533333  ...  15.133333  16.533333
# 1  24.323077  25.207692  27.261538  27.953846  ...  30.969231  29.292308
# 2  13.456250  13.331250  14.325000  14.887500  ...  14.437500  16.881250
# 3  27.151852  27.740741  28.833333  31.633333  ...  32.614815  36.648148
# 4  68.105263  69.407895  66.973684  75.578947  ...  86.997368  82.897368
#
#        Y2013      Y2014      Y2015      Y2016      Y2017      Y2018  \
# ...

# %%
# states.columns = states.iloc[0]
states=states.transpose()

# mh.rename(columns = {'dist_name':'year'}, inplace = True)

# %%
states.head()
# Out:
#                    0          1        2          3          4          5   \
# state_name         AN         AP       AR         AS         BR         CG
# Y1998       11.766667  17.684615     9.15  20.159259  55.215789  32.044444
# Y1999       11.733333  19.507692  11.0125  21.518519  55.060526  33.666667
# Y2000       12.866667  20.746154  11.4375  24.125926  60.981579      33.25
# Y2001       13.066667  23.592308  14.1125  26.044444  68.534211  38.983333
#
#               6      7          8     9   ...      26      27         28  \
# state_name    CH     DD         DL    DN  ...      PB      PY         RJ
# Y1998       30.6  21.95  80.588889  18.8  ...   47.08  19.975  45.509091
# Y1999       31.2  21.95  82.555556  19.1  ...    49.4   22.65  47.342424
# Y2000       36.4   22.8  91.244444  22.7  ...   57.32    23.7  47.739394
# Y2001       38.3  22.45  95.555556  24.0  ...  58.365  23.625  52.912121
#
# ...

# %%
states.columns
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
states.reset_index(level=0, inplace=True)
# mh = mh.drop(index=0)
# mh.rename(columns = {'dist_name':'year'}, inplace = True)

# %%
states.columns = states.iloc[0]

# %%
states = states.drop(labels=0, axis=0)

# %%
states.rename(columns = {'state_name':'year'}, inplace = True)

# %%
states.columns
# Out:
# Index(['year', 'AN', 'AP', 'AR', 'AS', 'BR', 'CG', 'CH', 'DD', 'DL', 'DN',
#        'GA', 'GJ', 'HP', 'HR', 'JH', 'JK', 'KA', 'KL', 'LD', 'MH', 'ML', 'MN',
#        'MP', 'MZ', 'NL', 'OR', 'PB', 'PY', 'RJ', 'SK', 'TN', 'TR', 'TS', 'UK',
#        'UP', 'WB'],
#       dtype='object', name=0)

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation = 90)
sns.pointplot(y='UP', x='year', data=states)
# Out:
# <AxesSubplot:xlabel='year', ylabel='UP'>

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation = 90)
sns.pointplot(x = 'year', y = 'PB', data = states)
# Out:
# <AxesSubplot:xlabel='year', ylabel='PB'>

# %%
# sns.scatterplot(data=states, x="mp", y="year")
plt.figure(figsize=(10,5))
plt.xticks(rotation = 90)
sns.pointplot(y='BR', x='year', data=states)
# Out:
# <AxesSubplot:xlabel='year', ylabel='BR'>

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation = 90)
sns.pointplot(y='DL', x='year', data=states)
# Out:
# <AxesSubplot:xlabel='year', ylabel='DL'>
